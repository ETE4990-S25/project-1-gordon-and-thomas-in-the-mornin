# %%
from items_and_backpack.backpack import Backpack


from game import intro_screen

bp = Backpack('.\\items_and_backpack\\back.json')



if __name__ == "__main__":
    intro_screen(bp)
# Out:
# --- Welcome to the Adventure Game ---
# 1) Explore
# 2) Examine Backpack
# 3) Search Item description
# 4) Craft Items
# 5) Exit and Save
# 10) HARD RESET BACKPACK
#
# [Reseting Backpack]
#
#
# --- Welcome to the Adventure Game ---
# 1) Explore
# 2) Examine Backpack
# 3) Search Item description
# 4) Craft Items
# 5) Exit and Save
# 10) HARD RESET BACKPACK
#
# [Exploring the world...]
#
# You are home
# What would you like to do?
# 1) Explore
# 2) Go back to main screen
# Invalid choice
#
# --- Welcome to the Adventure Game ---
# 1) Explore
# 2) Examine Backpack
# 3) Search Item description
# 4) Craft Items
# 5) Exit and Save
# 10) HARD RESET BACKPACK
#
# [Exploring the world...]
#
# You are home
# What would you like to do?
# 1) Explore
# 2) Go back to main screen
#
# Choose a direction to walk
# N) Walk North
# S) Walk South
# E) Walk East
# W) Walk West
# GH) Go Home
#
# Choose a direction to walk
# N) Walk North
# S) Walk South
# E) Walk East
# W) Walk West
# GH) Go Home
# You were attacked by a wild animal
#
#
#  --------------
#  You encountered a Wolf (Level 1)!
# You need 1 wins to defeat it.
#
#  --------------
#
# Invalid input. Enter a number.
#
#  --------------
#
# You won this round! Your guess was 15, total sum was 14.
# Wins to beat: 1/1
# Reminder: You need 1 wins to defeat the Wolf
# You defeated the Wolf!
# You found 1 rock
#
# Choose a direction to walk
# N) Walk North
# S) Walk South
# E) Walk East
# W) Walk West
# GH) Go Home
#
# Choose a direction to walk
# N) Walk North
# S) Walk South
# E) Walk East
# W) Walk West
# GH) Go Home
#
# Choose a direction to walk
# N) Walk North
# S) Walk South
# E) Walk East
# W) Walk West
# GH) Go Home
#
# Choose a direction to walk
# N) Walk North
# S) Walk South
# E) Walk East
# W) Walk West
# GH) Go Home
#
# Choose a direction to walk
# N) Walk North
# S) Walk South
# E) Walk East
# W) Walk West
# GH) Go Home
#
# Choose a direction to walk
# N) Walk North
# S) Walk South
# E) Walk East
# W) Walk West
# GH) Go Home
#
# Choose a direction to walk
# N) Walk North
# S) Walk South
# E) Walk East
# W) Walk West
# GH) Go Home
#
# Choose a direction to walk
# N) Walk North
# S) Walk South
# E) Walk East
# W) Walk West
# GH) Go Home
#
# Choose a direction to walk
# N) Walk North
# S) Walk South
# E) Walk East
# W) Walk West
# GH) Go Home
# You were attacked by a wild animal
#
#
#  --------------
#  You encountered a Wolf (Level 1)!
# You need 1 wins to defeat it.
#
#  --------------
#
# Invalid input. Enter a number.
#
#  --------------
#
# You lost this round!
# Wins to beat: 0/1
# Reminder: You need 1 wins to defeat the Wolf
#
#  --------------
#
# You won this round! Your guess was 15, total sum was 14.
# Wins to beat: 1/1
# Reminder: You need 1 wins to defeat the Wolf
# You defeated the Wolf!
# You found nothing
#
# Choose a direction to walk
# N) Walk North
# S) Walk South
# E) Walk East
# W) Walk West
# GH) Go Home
#
# Choose a direction to walk
# N) Walk North
# S) Walk South
# E) Walk East
# W) Walk West
# GH) Go Home
# You were attacked by a wild animal
#
#
#  --------------
#  You encountered a Wild Boar (Level 1)!
# You need 1 wins to defeat it.
#
#  --------------
#
# You won this round! Your guess was 15, total sum was 17.
# Wins to beat: 1/1
# Reminder: You need 1 wins to defeat the Wild Boar
# You defeated the Wild Boar!
# You found 3 rocks
#
# Choose a direction to walk
# N) Walk North
# S) Walk South
# E) Walk East
# W) Walk West
# GH) Go Home
# You are home
# What would you like to do?
# 1) Explore
# 2) Go back to main screen
#
# --- Welcome to the Adventure Game ---
# 1) Explore
# 2) Examine Backpack
# 3) Search Item description
# 4) Craft Items
# 5) Exit and Save
# 10) HARD RESET BACKPACK
#
# [Opening your backpack...]
#
# Item 		| Count
# ----------------
# rock 		| 4
#
# --- Welcome to the Adventure Game ---
# 1) Explore
# 2) Examine Backpack
# 3) Search Item description
# 4) Craft Items
# 5) Exit and Save
# 10) HARD RESET BACKPACK
#
# [Crafting items...]
#
# You can craft the following items:
# 1) stone
# Enter '0' to go back
# stone crafted
#
# --- Welcome to the Adventure Game ---
# 1) Explore
# 2) Examine Backpack
# 3) Search Item description
# 4) Craft Items
# 5) Exit and Save
# 10) HARD RESET BACKPACK
#
# [Viewing item description...]
#
# Description of stone: smooth rock
#
# --- Welcome to the Adventure Game ---
# 1) Explore
# 2) Examine Backpack
# 3) Search Item description
# 4) Craft Items
# 5) Exit and Save
# 10) HARD RESET BACKPACK
#
# [Opening your backpack...]
#
# Item 		| Count
# ----------------
# rock 		| 2
# stone 		| 1
#
# --- Welcome to the Adventure Game ---
# 1) Explore
# 2) Examine Backpack
# 3) Search Item description
# 4) Craft Items
# 5) Exit and Save
# 10) HARD RESET BACKPACK
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 11
#       6 bp = Backpack('.\\items_and_backpack\\back.json')
#      10 if __name__ == "__main__":
# ---> 11     intro_screen(bp)
#
# File e:\CPP\ETE4990\project-1-gordon-and-thomas-in-the-mornin\game.py:124, in intro_screen(bp)
#     122 if choice == "1":
#     123     print("\n[Exploring the world...]\n")
# --> 124     go_Home(bp)
#     125 elif choice == "2":
#     126     print("\n[Opening your backpack...]\n")
#
# File e:\CPP\ETE4990\project-1-gordon-and-thomas-in-the-mornin\game.py:78, in go_Home(bp)
#      76 choice = input("Select an option (1-2): ")
#      77 if choice == "1":
# ---> 78     move_Direction(bp)
#      79 elif choice == "2":
#      80     intro_screen(bp)
#
# File e:\CPP\ETE4990\project-1-gordon-and-thomas-in-the-mornin\game.py:60, in move_Direction(bp)
#      58     position[1] -= 1
#      59 elif choice == "gh":
# ---> 60     go_Home(bp)
#      61 else:
#      62     print("Invalid direction")
#
# File e:\CPP\ETE4990\project-1-gordon-and-thomas-in-the-mornin\game.py:80, in go_Home(bp)
#      78     move_Direction(bp)
#      79 elif choice == "2":
# ---> 80     intro_screen(bp)
#      81 else:
#      82     print("Invalid choice")
#
# File e:\CPP\ETE4990\project-1-gordon-and-thomas-in-the-mornin\game.py:120, in intro_screen(bp)
#     117 print("5) Exit and Save")
#     118 print("10) HARD RESET BACKPACK")
# --> 120 choice = input("Select an option (1-5): ")
#     122 if choice == "1":
#     123     print("\n[Exploring the world...]\n")
#
# File c:\Python312\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File c:\Python312\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
